# %%
import torch
import data as Data
import model as Model
import argparse
import logging
import core.logger as Logger
import core.metrics as Metrics
from tensorboardX import SummaryWriter
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
dataset_opt = {
    "name": "CelebaHQ",
    "mode": "LRHR",
    "dataroot": "data/datasets/femurPNGs/femur_LH_64_256",
    "datatype": "img", #lmdb or img, path of img files
    "l_resolution": 64,
    "r_resolution": 256,
    "data_len": -1, # data length in validation 
    "chtype": "L",
    "use_shuffle": True
}

val_set = Data.create_dataset(dataset_opt, 'val')
val_loader = Data.create_dataloader(
        val_set, dataset_opt, 'val')

# %%
model_opt = {
    "gpu_ids": [0],
    "phase": "val",
    "distributed": False,
    "model": {
        "which_model_G": "sr3",
        "finetune_norm": False,
        "unet": {
            "in_channel": 2,
            "out_channel": 1,
            "inner_channel": 64,
            "channel_multiplier": [
                1,
                2,
                4,
                8,
                8
            ],
            "attn_res": [
                32
            ],
            "res_blocks": 2,
            "dropout": 0.1
        },
        "beta_schedule": {
            "train": {
                "schedule": "cosine",
                "n_timestep": 2000,
                "linear_start": 1e-6,
                "linear_end": 1e-2
            },
            "val": {
                "schedule": "cosine",
                "n_timestep": 2000,
                "linear_start": 1e-6,
                "linear_end": 1e-2
            }
        },
        "diffusion": {
            "image_size": 256,
            "channels": 1,
            "conditional": True
        }
    },
    "train": {
        "n_iter": 1000000,
        "val_freq": 1e4,
        "save_checkpoint_freq": 1e4,
        "print_freq": 200,
        "optimizer": {
            "type": "adam",
            "lr": 1e-4
        },
        "ema_scheduler": {
            "step_start_ema": 5000,
            "update_ema_every": 1,
            "ema_decay": 0.9999
        }
    },
    "path": {
        "log": "logs",
        "tb_logger": "tb_logger",
        "results": "results",
        "checkpoint": "checkpoint",
        "resume_state": "experiments/sr_ffhq_211013_112422/checkpoint/I380000_E130"
#         "resume_state": "experiments/sr_ffhq_211010_120508/checkpoint/I90000_E31"
#         "resume_state": "experiments/sr_ffhq_211010_120508/checkpoint/I160000_E55"
    }
}

diffusion = Model.create_model(model_opt)

# %%
diffusion.set_new_noise_schedule(model_opt['model']['beta_schedule'][model_opt['phase']], schedule_phase=model_opt['phase'])

# %%
def test_image(val_data, model, result_path, scalefactor):
    diffusion=model
    diffusion.feed_data(val_data)
    diffusion.test(continous=False)
    visuals = diffusion.get_current_visuals()
    sr_img = Metrics.tensor2img(visuals['SR'])  # uint8
    hr_img = Metrics.tensor2img(visuals['HR'])  # uint8
    lr_img = Metrics.tensor2img(visuals['LR'])  # uint8
    fake_img = Metrics.tensor2img(visuals['INF'])  # uint8
    lr_img = np.repeat(np.repeat(lr_img, scalefactor, axis=0), scalefactor, axis=1)
    out_img = np.concatenate((hr_img,lr_img,fake_img,sr_img),axis=1)
    Metrics.save_img(out_img, '{}.png'.format(result_path))

#     # generation
#     Metrics.save_img(
#         hr_img, '{}_hr.png'.format(result_path))
#     Metrics.save_img(
#         sr_img, '{}_sr.png'.format(result_path))
#     Metrics.save_img(
#         lr_img, '{}_lr.png'.format(result_path))
#     Metrics.save_img(
#         fake_img, '{}_inf.png'.format(result_path))

# %%
def test_image_continuous(val_data, model, result_path, scalefactor):
    diffusion=model
    diffusion.feed_data(val_data)
    diffusion.test(continous=True)
    visuals = diffusion.get_current_visuals()
    sr_img = Metrics.tensor2img(visuals['SR'])  # uint8
    srflat = np.concatenate([sr_img[:,:,i] for i in range(len(sr_img[0,0,:]))],axis=1)
    Metrics.save_img(srflat, '{}.png'.format(result_path))

# %%
idx = [500]#[1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
scalefactor = int(dataset_opt['r_resolution']/dataset_opt['l_resolution'])

for i,  val_data in enumerate(val_loader):
    if i in idx:
        test_image_continuous(val_data, diffusion, "misc/continuousim_E45_{}_r4".format(i), scalefactor)
    elif i > max(idx): 
        break
    else:
        continue
# Out:
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.61it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.60it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.61it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.61it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.61it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.62it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.60it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.60it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [02:38<00:00, 12.61it/s]

# %%
idx = [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
scalefactor = int(dataset_opt['r_resolution']/dataset_opt['l_resolution'])

for i,  val_data in enumerate(val_loader):
    if i in idx:
        test_image(val_data, diffusion, "misc/testim_E45_{}_cosinesched_r1".format(i), scalefactor)
    elif i > max(idx): 
        break
    else:
        continue
#     val_data = np.transpose(np.tile(np.squeeze(np.array(val_data['HR'])),(3,1,1)),[1,2,0])
#     val_data = -1*val_data
#     plt.imshow(val_data)
# Out:
# sampling loop time step: 100%|██████████| 2000/2000 [01:08<00:00, 29.10it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [01:08<00:00, 29.00it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [01:11<00:00, 28.14it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [01:11<00:00, 27.90it/s]
# sampling loop time step: 100%|██████████| 2000/2000 [01:12<00:00, 27.71it/s]
# sampling loop time step:   4%|▍         | 86/2000 [00:02<01:06, 28.88it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-bf0629065e84> in <module>
#       4 for i,  val_data in enumerate(val_loader):
#       5     if i in idx:
# ----> 6         test_image(val_data, diffusion, "misc/testim_E45_{}_cosinesched_r1".format(i), scalefactor)
#       7     elif i > max(idx):
#       8         break
#
# <ipython-input-5-d3b70ca2dc47> in test_image(val_data, model, result_path, scalefactor)
#       2     diffusion=model
#       3     diffusion.feed_data(val_data)
# ----> 4     diffusion.test(continous=False)
#       5     visuals = diffusion.get_current_visuals()
#       6     sr_img = Metrics.tensor2img(visuals['SR'])  # uint8
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/model.py in test(self, continous)
#      65                     self.data['SR'], continous)
#      66             else:
# ---> 67                 self.SR = self.netG.super_resolution(
#      68                     self.data['SR'], continous)
#      69         self.netG.train()
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/diffusion.py in super_resolution(self, x_in, continous)
#     208     @torch.no_grad()
#     209     def super_resolution(self, x_in, continous=False):
# --> 210         return self.p_sample_loop(x_in, continous)
#     211
#     212     def q_sample(self, x_start, continuous_sqrt_alpha_cumprod, noise=None):
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/diffusion.py in p_sample_loop(self, x_in, continous)
#     192             ret_img = x
#     193             for i in tqdm(reversed(range(0, self.num_timesteps)), desc='sampling loop time step', total=self.num_timesteps):
# --> 194                 img = self.p_sample(img, i, condition_x=x)
#     195                 if i % sample_inter == 0:
#     196                     ret_img = torch.cat([ret_img, img], dim=0)
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/diffusion.py in p_sample(self, x, t, clip_denoised, condition_x)
#     169     @torch.no_grad()
#     170     def p_sample(self, x, t, clip_denoised=True, condition_x=None):
# --> 171         model_mean, model_log_variance = self.p_mean_variance(
#     172             x=x, t=t, clip_denoised=clip_denoised, condition_x=condition_x)
#     173         noise = torch.randn_like(x) if t > 0 else torch.zeros_like(x)
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/diffusion.py in p_mean_variance(self, x, t, clip_denoised, condition_x)
#     155         if condition_x is not None:
#     156             x_recon = self.predict_start_from_noise(
# --> 157                 x, t=t, noise=self.denoise_fn(torch.cat([condition_x, x], dim=1), noise_level))
#     158         else:
#     159             x_recon = self.predict_start_from_noise(
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/unet.py in forward(self, x, time)
#     254         for layer in self.ups:
#     255             if isinstance(layer, ResnetBlocWithAttn):
# --> 256                 x = layer(torch.cat((x, feats.pop()), dim=1), t)
#     257             else:
#     258                 x = layer(x)
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/unet.py in forward(self, x, time_emb)
#     153
#     154     def forward(self, x, time_emb):
# --> 155         x = self.res_block(x, time_emb)
#     156         if(self.with_attn):
#     157             x = self.attn(x)
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/unet.py in forward(self, x, time_emb)
#     107         h = self.block1(x)
#     108         h = self.noise_func(h, time_emb)
# --> 109         h = self.block2(h)
#     110         return h + self.res_conv(x)
#     111
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/users/trevor/repos/diffusion/iterative_refinement/model/sr3_modules/unet.py in forward(self, x)
#      89
#      90     def forward(self, x):
# ---> 91         return self.block(x)
#      92
#      93
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/modules/normalization.py in forward(self, input)
#     244
#     245     def forward(self, input: Tensor) -> Tensor:
# --> 246         return F.group_norm(
#     247             input, self.num_groups, self.weight, self.bias, self.eps)
#     248
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/functional.py in group_norm(input, num_groups, weight, bias, eps)
#    2215     if has_torch_function_unary(input):
#    2216         return handle_torch_function(group_norm, (input,), input, num_groups, weight=weight, bias=bias, eps=eps)
# -> 2217     _verify_batch_size([input.size(0) * input.size(1) // num_groups, num_groups] + list(input.size()[2:]))
#    2218     return torch.group_norm(input, num_groups, weight, bias, eps, torch.backends.cudnn.enabled)
#    2219
#
# ~/.conda/envs/diffusion/lib/python3.9/site-packages/torch/nn/functional.py in _verify_batch_size(size)
#    2109     #   if reduce(mul, size[2:], size[0]) == 1
#    2110     size_prods = size[0]
# -> 2111     for i in range(len(size) - 2):
#    2112         size_prods *= size[i + 2]
#    2113     if size_prods == 1:
#
# KeyboardInterrupt:
