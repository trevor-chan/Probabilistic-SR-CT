# %%
import pydicom as dicom
import cv2   
import glob
from tqdm import tqdm
from torchvision import transforms, utils
from PIL import Image
import numpy as np

# %%
glob.glob('../../../../datasets/femurDCMs/*/*.DCM')
# Out:
# []

# %%
# specify your image path
images_path = '~/**/trevor/datasets/femurDCMs/*/*.DCM'

for impath in tqdm(glob.glob(images_path)):
    print(impath)
    ds = dicom.dcmread(image_path)

    pixel_array_numpy = ds.pixel_array
    image_format = '.png' # or '.jpg'
    image_path = image_path.replace('.DCM', image_format)
    cv2.imwrite(image_path, pixel_array_numpy)
print('done')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1f71bb89a841> in <module>
#       2 images_path = '~/**/trevor/datasets/femurDCMs/*/*.DCM'
#       3
# ----> 4 for impath in tqdm(glob(images_path)):
#       5     print(impath)
#       6     ds = dicom.dcmread(image_path)
#
# TypeError: 'module' object is not callable

# %%
# !ls ~/**/trevor/datasets/femurDCMs/*/
# Out:
# /home/vbbproc/users/trevor/datasets/femurDCMs/0058708-01/:
# C0000481_00000.DCM  C0000481_00500.DCM	C0000481_01000.DCM  C0000481_01500.DCM
# C0000481_00001.DCM  C0000481_00501.DCM	C0000481_01001.DCM  C0000481_01501.DCM
# C0000481_00002.DCM  C0000481_00502.DCM	C0000481_01002.DCM  C0000481_01502.DCM
# C0000481_00003.DCM  C0000481_00503.DCM	C0000481_01003.DCM  C0000481_01503.DCM
# C0000481_00004.DCM  C0000481_00504.DCM	C0000481_01004.DCM  C0000481_01504.DCM
# C0000481_00005.DCM  C0000481_00505.DCM	C0000481_01005.DCM  C0000481_01505.DCM
# C0000481_00006.DCM  C0000481_00506.DCM	C0000481_01006.DCM  C0000481_01506.DCM
# C0000481_00007.DCM  C0000481_00507.DCM	C0000481_01007.DCM  C0000481_01507.DCM
# C0000481_00008.DCM  C0000481_00508.DCM	C0000481_01008.DCM  C0000481_01508.DCM
# C0000481_00009.DCM  C0000481_00509.DCM	C0000481_01009.DCM  C0000481_01509.DCM
# C0000481_00010.DCM  C0000481_00510.DCM	C0000481_01010.DCM  C0000481_01510.DCM
# ...
